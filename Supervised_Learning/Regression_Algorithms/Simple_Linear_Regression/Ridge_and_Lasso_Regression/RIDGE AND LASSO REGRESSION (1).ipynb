# %% [markdown]
# ## Ridge and Lasso Regression

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("my_data.csv")
df
# Out:
#     Size  Bedrooms  Age  Distance     Price
# 0   1860         4   28        12   9273236
# 1   2294         4   25         5  11483735
# 2   2130         4   39         5  10609740
# 3   2095         3   33        27  10411226
# 4   2638         3    1        23  13172992
# ..   ...       ...  ...       ...       ...
# 95  3062         2   48         5  15180717
# 96  1064         3   49        24   5155308
# 97  3568         4    2        29  17826449
# 98  2367         2    1        17  11848490
# 99  2152         3   48        14  10606150
#
# [100 rows x 5 columns]

# %% [raw]
# ridge regression------>shrink or reduce the coefficient but keeps all variables----->ex:-2k to 1800-------->reduce the overfitting
# lasso regression------->removes less importance features by setting some coefficients to zero

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import mean_squared_error

# %%
x=df[["Size","Bedrooms","Age","Distance"]]
y=df["Price"]

# %%
#x=df.drop("Price")
#y=df["Price"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
lr=LinearRegression()
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ridge=Ridge(alpha=10) #alpha controls penalty strength
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=10)

# %%
lasso=Lasso(alpha=10)
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=10)

# %%
coef_df=pd.DataFrame({"Feature":x.columns,"Linear":lr.coef_,"Ridge":ridge.coef_,"Lasso":lasso.coef_})
coef_df
# Out:
#     Feature        Linear         Ridge         Lasso
# 0      Size   5004.473043   5004.392018   5004.472542
# 1  Bedrooms  16647.975109  15020.648551  16639.117245
# 2       Age  -2946.813283  -2928.218370  -2946.678019
# 3  Distance  -1470.284141  -1442.900906  -1470.018331
