# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\chars\\Downloads\\archive (2)\\house_price_regression_dataset.csv")
df
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0              1360             2              1        1981  0.599637
# 1              4272             3              3        2016  4.753014
# 2              3592             1              2        2016  3.634823
# 3               966             1              2        1977  2.730667
# 4              4926             2              1        1993  4.699073
# ..              ...           ...            ...         ...       ...
# 995            3261             4              1        1978  2.165110
# 996            3179             1              2        1999  2.977123
# 997            2606             4              2        1962  4.055067
# 998            4723             5              2        1950  1.930921
# 999            3268             4              2        1983  3.108790
#
#      Garage_Size  Neighborhood_Quality   House_Price
# 0              0                     5  2.623829e+05
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
x=df[["Square_Footage","Num_Bedrooms","Num_Bathrooms","Lot_Size"]]
y=df["House_Price"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 840084.84678296,  490464.25899111,  970659.21579265,
#        1046970.17556641,  773270.81152465,  759900.31969919,
#         983216.72390046,  876694.50748186,  798873.69329323,
#         909878.47594627,  766689.93303112,  651581.99911307,
#         192493.1408617 , 1068166.79809893,  516066.91794242,
#         220786.53043759,  472584.24192018,  368043.5756747 ,
#         739706.61798903,  363175.54541004,  746676.93582562,
#         503943.16576375,  680298.7594464 ,  894177.86730529,
#         447043.98593937,  381669.08927467,  488622.92534346,
#         465470.92548116,  228261.55791756,  488445.29226364,
#         285571.00984574,  928612.78099676,  766864.69901695,
#         360395.31229547,  505493.60069478,  784646.30249141,
#         482527.05793664,  569808.89490866,  278903.56414351,
#         183555.80764342,  329484.56710283,  281448.79875142,
#         533683.33573407,  316618.02854727, 1066806.72067935,
# ...

# %%
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 511375124.7082892

# %%
plt.scatter(x=y_test, y=y_pred, color='blue')#, label='Data points')
plt.plot(x, model.predict(x), color='red')#, label='Regression Line') 
plt.xlabel('House Size (sqft)')
plt.ylabel('House Price ($)')
plt.title('House Price vs. Size')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import seaborn as sns

# %%
sns.scatterplot(x=y_test,y=y_pred)
plt.xlabel("house price")
plt.ylabel("house prediction")
plt.title("actual price vs predict price")
plt.show()
